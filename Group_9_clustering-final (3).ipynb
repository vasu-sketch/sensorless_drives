# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import numpy as np
import pandas as pd
from yellowbrick.cluster import KElbowVisualizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('Group_9_data_cleaned.csv', index_col=0)
df.head(10)
# Out:
#       current_1     current_2  current_3     current_4     current_5  \
# 0 -3.014600e-07  8.260300e-06  -0.000012 -2.309800e-06 -1.438600e-06
# 1  2.913200e-06 -5.247700e-06   0.000003 -6.056100e-06  2.778900e-06
# 2 -2.951700e-06 -3.184000e-06  -0.000016 -1.208400e-06 -1.575300e-06
# 3 -1.322600e-06  8.820100e-06  -0.000016 -4.811100e-06 -7.282900e-07
# 4 -6.836600e-08  5.666300e-07  -0.000026 -6.490100e-06 -7.940600e-07
# 5 -9.584900e-07  5.214300e-08  -0.000047  6.453700e-07 -2.304100e-06
# 6 -1.783700e-06  1.303600e-06  -0.000038 -7.083900e-06  6.706300e-06
# 7 -2.566600e-06 -1.679500e-07   0.000015 -1.598400e-06  8.709200e-07
# 8 -5.474000e-06  1.086500e-07  -0.000011 -1.815600e-06  4.757800e-07
# 9  2.825600e-06  6.067600e-06   0.000118 -4.347500e-06  1.492300e-06
#
#    current_6  current_7  current_8  current_9  current_10  ...  current_40  \
# 0  -0.000021   0.031718   0.031710   0.031721   -0.032963  ...    -0.63308
# 1  -0.000004   0.030804   0.030810   0.030806   -0.033520  ...    -0.59314
# 2   0.000017   0.032877   0.032880   0.032896   -0.029834  ...    -0.63252
# 3   0.000004   0.029410   0.029401   0.029417   -0.030156  ...    -0.62289
# 4   0.000013   0.030119   0.030119   0.030145   -0.031393  ...    -0.63010
# 5   0.000055   0.031154   0.031154   0.031201   -0.032789  ...    -0.61124
# 6   0.000022   0.033805   0.033804   0.033841   -0.033345  ...    -0.62501
# 7   0.000015   0.031071   0.031071   0.031056   -0.029695  ...    -0.63618
# 8   0.000024   0.031309   0.031308   0.031319   -0.031344  ...    -0.62465
# 9  -0.000003   0.030947   0.030941   0.030823   -0.032171  ...    -0.58170
#
#    current_41  current_42  current_43  current_44  current_45  current_46  \
# 0      2.9646      8.1198     -1.4961     -1.4961     -1.4961     -1.4996
# 1      7.6252      6.1690     -1.4967     -1.4967     -1.4967     -1.5005
# 2      2.7784      5.3017     -1.4983     -1.4983     -1.4982     -1.4985
# 3      6.5534      6.2606     -1.4963     -1.4963     -1.4963     -1.4975
# 4      4.5155      9.5231     -1.4958     -1.4958     -1.4958     -1.4959
# 5      5.8337     17.9893     -1.4956     -1.4956     -1.4956     -1.4973
# 6     17.6180      9.0823     -1.4960     -1.4960     -1.4959     -1.4954
# 7     12.8380      4.9079     -1.4990     -1.4990     -1.4990     -1.4968
# 8      2.9841      6.6883     -1.4955     -1.4955     -1.4955     -1.4947
# 9      2.0511      8.8939     -1.4963     -1.4963     -1.4963     -1.4943
#
#    current_47  current_48  output
# 0     -1.4996     -1.4996       1
# 1     -1.5005     -1.5005       1
# 2     -1.4985     -1.4985       1
# 3     -1.4975     -1.4976       1
# 4     -1.4959     -1.4959       1
# 5     -1.4972     -1.4973       1
# 6     -1.4954     -1.4953       1
# 7     -1.4968     -1.4968       1
# 8     -1.4947     -1.4947       1
# 9     -1.4943     -1.4943       1
#
# [10 rows x 49 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58509 entries, 0 to 58508
# Data columns (total 49 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   current_1   58509 non-null  float64
#  1   current_2   58509 non-null  float64
#  2   current_3   58509 non-null  float64
#  3   current_4   58509 non-null  float64
#  4   current_5   58509 non-null  float64
#  5   current_6   58509 non-null  float64
#  6   current_7   58509 non-null  float64
#  7   current_8   58509 non-null  float64
#  8   current_9   58509 non-null  float64
#  9   current_10  58509 non-null  float64
#  10  current_11  58509 non-null  float64
#  11  current_12  58509 non-null  float64
#  12  current_13  58509 non-null  float64
#  13  current_14  58509 non-null  float64
#  14  current_15  58509 non-null  float64
#  15  current_16  58509 non-null  float64
#  16  current_17  58509 non-null  float64
#  17  current_18  58509 non-null  float64
#  18  current_19  58509 non-null  float64
#  19  current_20  58509 non-null  float64
#  20  current_21  58509 non-null  float64
#  21  current_22  58509 non-null  float64
#  22  current_23  58509 non-null  float64
#  23  current_24  58509 non-null  float64
#  24  current_25  58509 non-null  float64
#  25  current_26  58509 non-null  float64
#  26  current_27  58509 non-null  float64
#  27  current_28  58509 non-null  float64
#  28  current_29  58509 non-null  float64
#  29  current_30  58509 non-null  float64
#  30  current_31  58509 non-null  float64
#  31  current_32  58509 non-null  float64
#  32  current_33  58509 non-null  float64
#  33  current_34  58509 non-null  float64
#  34  current_35  58509 non-null  float64
#  35  current_36  58509 non-null  float64
#  36  current_37  58509 non-null  float64
#  37  current_38  58509 non-null  float64
#  38  current_39  58509 non-null  float64
#  39  current_40  58509 non-null  float64
#  40  current_41  58509 non-null  float64
#  41  current_42  58509 non-null  float64
#  42  current_43  58509 non-null  float64
#  43  current_44  58509 non-null  float64
#  44  current_45  58509 non-null  float64
#  45  current_46  58509 non-null  float64
#  46  current_47  58509 non-null  float64
#  47  current_48  58509 non-null  float64
#  48  output      58509 non-null  int64
# dtypes: float64(48), int64(1)
# memory usage: 22.3 MB

# %%
X = df.drop(["output"], axis=1)
X
# Out:
#           current_1     current_2  current_3  current_4     current_5  \
# 0     -3.014600e-07  8.260300e-06  -0.000012  -0.000002 -1.438600e-06
# 1      2.913200e-06 -5.247700e-06   0.000003  -0.000006  2.778900e-06
# 2     -2.951700e-06 -3.184000e-06  -0.000016  -0.000001 -1.575300e-06
# 3     -1.322600e-06  8.820100e-06  -0.000016  -0.000005 -7.282900e-07
# 4     -6.836600e-08  5.666300e-07  -0.000026  -0.000006 -7.940600e-07
# ...             ...           ...        ...        ...           ...
# 58504 -9.982500e-06  1.854900e-06  -0.000021   0.000017 -5.910200e-06
# 58505 -1.055400e-05  1.983500e-05   0.000031  -0.000018 -6.547550e-05
# 58506 -5.857700e-06  1.859400e-05  -0.000102  -0.000003  3.827500e-06
# 58507 -4.441100e-06  3.396900e-05  -0.000294   0.000005  6.500800e-06
# 58508 -8.853300e-06  5.225900e-05   0.000072   0.000010  3.795600e-06
#
#        current_6  current_7  current_8  current_9  current_10  ...  \
# 0      -0.000021   0.031718   0.031710   0.031721   -0.032963  ...
# 1      -0.000004   0.030804   0.030810   0.030806   -0.033520  ...
# 2       0.000017   0.032877   0.032880   0.032896   -0.029834  ...
# 3       0.000004   0.029410   0.029401   0.029417   -0.030156  ...
# 4       0.000013   0.030119   0.030119   0.030145   -0.031393  ...
# ...          ...        ...        ...        ...         ...  ...
# 58504  -0.000098  -0.083417  -0.083419  -0.083398   -0.111281  ...
# 58505   0.000289  -0.085131  -0.085151  -0.085182   -0.111281  ...
# 58506   0.000117  -0.081989  -0.082008  -0.081906   -0.111281  ...
# 58507   0.000087  -0.081500  -0.081534  -0.081093   -0.111281  ...
# 58508  -0.000032  -0.083034  -0.083086  -0.083159   -0.111281  ...
#
#        current_39  current_40  current_41  current_42  current_43  current_44  \
# 0         6.01680    -0.63308      2.9646      8.1198     -1.4961     -1.4961
# 1         3.60480    -0.59314      7.6252      6.1690     -1.4967     -1.4967
# 2         5.80070    -0.63252      2.7784      5.3017     -1.4983     -1.4983
# 3        18.20455    -0.62289      6.5534      6.2606     -1.4963     -1.4963
# 4         5.05820    -0.63010      4.5155      9.5231     -1.4958     -1.4958
# ...           ...         ...         ...         ...         ...         ...
# 58504     7.39390    -0.52907      1.4641      7.0032     -1.5024     -1.5025
# 58505     3.85500    -0.51971      3.3275      2.3072     -1.5024     -1.5025
# 58506    12.69400    -0.51103     18.5458      9.0437     -1.5035     -1.5035
# 58507     4.39240    -0.52033      1.3890     10.7430     -1.5029     -1.5029
# 58508     5.65120    -0.50974      1.6026      4.5773     -1.5039     -1.5040
#
#        current_45  current_46  current_47  current_48
# 0         -1.4961     -1.4996    -1.49960    -1.49960
# 1         -1.4967     -1.5005    -1.50050    -1.50050
# 2         -1.4982     -1.4985    -1.49850    -1.49850
# 3         -1.4963     -1.4975    -1.49750    -1.49760
# 4         -1.4958     -1.4959    -1.49590    -1.49590
# ...           ...         ...         ...         ...
# 58504     -1.5023     -1.4933    -1.49330    -1.49330
# 58505     -1.5024     -1.4925    -1.49250    -1.49260
# 58506     -1.5039     -1.4911    -1.49135    -1.49125
# 58507     -1.5030     -1.4932    -1.49320    -1.49310
# 58508     -1.5036     -1.4945    -1.49460    -1.49430
#
# [58509 rows x 48 columns]

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(X)

# %%
km = KMeans(n_clusters= 11)
km.fit(X)
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=11)

# %%
cluster = km.predict(X)
cluster
# Out:
# array([0, 9, 0, ..., 3, 5, 0])

# %%
X['Cluster'] = cluster
X
# Out:
#           current_1     current_2  current_3  current_4     current_5  \
# 0     -3.014600e-07  8.260300e-06  -0.000012  -0.000002 -1.438600e-06
# 1      2.913200e-06 -5.247700e-06   0.000003  -0.000006  2.778900e-06
# 2     -2.951700e-06 -3.184000e-06  -0.000016  -0.000001 -1.575300e-06
# 3     -1.322600e-06  8.820100e-06  -0.000016  -0.000005 -7.282900e-07
# 4     -6.836600e-08  5.666300e-07  -0.000026  -0.000006 -7.940600e-07
# ...             ...           ...        ...        ...           ...
# 58504 -9.982500e-06  1.854900e-06  -0.000021   0.000017 -5.910200e-06
# 58505 -1.055400e-05  1.983500e-05   0.000031  -0.000018 -6.547550e-05
# 58506 -5.857700e-06  1.859400e-05  -0.000102  -0.000003  3.827500e-06
# 58507 -4.441100e-06  3.396900e-05  -0.000294   0.000005  6.500800e-06
# 58508 -8.853300e-06  5.225900e-05   0.000072   0.000010  3.795600e-06
#
#        current_6  current_7  current_8  current_9  current_10  ...  \
# 0      -0.000021   0.031718   0.031710   0.031721   -0.032963  ...
# 1      -0.000004   0.030804   0.030810   0.030806   -0.033520  ...
# 2       0.000017   0.032877   0.032880   0.032896   -0.029834  ...
# 3       0.000004   0.029410   0.029401   0.029417   -0.030156  ...
# 4       0.000013   0.030119   0.030119   0.030145   -0.031393  ...
# ...          ...        ...        ...        ...         ...  ...
# 58504  -0.000098  -0.083417  -0.083419  -0.083398   -0.111281  ...
# 58505   0.000289  -0.085131  -0.085151  -0.085182   -0.111281  ...
# 58506   0.000117  -0.081989  -0.082008  -0.081906   -0.111281  ...
# 58507   0.000087  -0.081500  -0.081534  -0.081093   -0.111281  ...
# 58508  -0.000032  -0.083034  -0.083086  -0.083159   -0.111281  ...
#
#        current_40  current_41  current_42  current_43  current_44  current_45  \
# 0        -0.63308      2.9646      8.1198     -1.4961     -1.4961     -1.4961
# 1        -0.59314      7.6252      6.1690     -1.4967     -1.4967     -1.4967
# 2        -0.63252      2.7784      5.3017     -1.4983     -1.4983     -1.4982
# 3        -0.62289      6.5534      6.2606     -1.4963     -1.4963     -1.4963
# 4        -0.63010      4.5155      9.5231     -1.4958     -1.4958     -1.4958
# ...           ...         ...         ...         ...         ...         ...
# 58504    -0.52907      1.4641      7.0032     -1.5024     -1.5025     -1.5023
# 58505    -0.51971      3.3275      2.3072     -1.5024     -1.5025     -1.5024
# 58506    -0.51103     18.5458      9.0437     -1.5035     -1.5035     -1.5039
# 58507    -0.52033      1.3890     10.7430     -1.5029     -1.5029     -1.5030
# 58508    -0.50974      1.6026      4.5773     -1.5039     -1.5040     -1.5036
#
#        current_46  current_47  current_48  Cluster
# 0         -1.4996    -1.49960    -1.49960        0
# 1         -1.5005    -1.50050    -1.50050        9
# 2         -1.4985    -1.49850    -1.49850        0
# 3         -1.4975    -1.49750    -1.49760        8
# 4         -1.4959    -1.49590    -1.49590        6
# ...           ...         ...         ...      ...
# 58504     -1.4933    -1.49330    -1.49330       10
# 58505     -1.4925    -1.49250    -1.49260        0
# 58506     -1.4911    -1.49135    -1.49125        3
# 58507     -1.4932    -1.49320    -1.49310        5
# 58508     -1.4945    -1.49460    -1.49430        0
#
# [58509 rows x 49 columns]

# %%
c = X.drop(columns=['Cluster'])
c
# Out:
#           current_1     current_2  current_3  current_4     current_5  \
# 0     -3.014600e-07  8.260300e-06  -0.000012  -0.000002 -1.438600e-06
# 1      2.913200e-06 -5.247700e-06   0.000003  -0.000006  2.778900e-06
# 2     -2.951700e-06 -3.184000e-06  -0.000016  -0.000001 -1.575300e-06
# 3     -1.322600e-06  8.820100e-06  -0.000016  -0.000005 -7.282900e-07
# 4     -6.836600e-08  5.666300e-07  -0.000026  -0.000006 -7.940600e-07
# ...             ...           ...        ...        ...           ...
# 58504 -9.982500e-06  1.854900e-06  -0.000021   0.000017 -5.910200e-06
# 58505 -1.055400e-05  1.983500e-05   0.000031  -0.000018 -6.547550e-05
# 58506 -5.857700e-06  1.859400e-05  -0.000102  -0.000003  3.827500e-06
# 58507 -4.441100e-06  3.396900e-05  -0.000294   0.000005  6.500800e-06
# 58508 -8.853300e-06  5.225900e-05   0.000072   0.000010  3.795600e-06
#
#        current_6  current_7  current_8  current_9  current_10  ...  \
# 0      -0.000021   0.031718   0.031710   0.031721   -0.032963  ...
# 1      -0.000004   0.030804   0.030810   0.030806   -0.033520  ...
# 2       0.000017   0.032877   0.032880   0.032896   -0.029834  ...
# 3       0.000004   0.029410   0.029401   0.029417   -0.030156  ...
# 4       0.000013   0.030119   0.030119   0.030145   -0.031393  ...
# ...          ...        ...        ...        ...         ...  ...
# 58504  -0.000098  -0.083417  -0.083419  -0.083398   -0.111281  ...
# 58505   0.000289  -0.085131  -0.085151  -0.085182   -0.111281  ...
# 58506   0.000117  -0.081989  -0.082008  -0.081906   -0.111281  ...
# 58507   0.000087  -0.081500  -0.081534  -0.081093   -0.111281  ...
# 58508  -0.000032  -0.083034  -0.083086  -0.083159   -0.111281  ...
#
#        current_39  current_40  current_41  current_42  current_43  current_44  \
# 0         6.01680    -0.63308      2.9646      8.1198     -1.4961     -1.4961
# 1         3.60480    -0.59314      7.6252      6.1690     -1.4967     -1.4967
# 2         5.80070    -0.63252      2.7784      5.3017     -1.4983     -1.4983
# 3        18.20455    -0.62289      6.5534      6.2606     -1.4963     -1.4963
# 4         5.05820    -0.63010      4.5155      9.5231     -1.4958     -1.4958
# ...           ...         ...         ...         ...         ...         ...
# 58504     7.39390    -0.52907      1.4641      7.0032     -1.5024     -1.5025
# 58505     3.85500    -0.51971      3.3275      2.3072     -1.5024     -1.5025
# 58506    12.69400    -0.51103     18.5458      9.0437     -1.5035     -1.5035
# 58507     4.39240    -0.52033      1.3890     10.7430     -1.5029     -1.5029
# 58508     5.65120    -0.50974      1.6026      4.5773     -1.5039     -1.5040
#
#        current_45  current_46  current_47  current_48
# 0         -1.4961     -1.4996    -1.49960    -1.49960
# 1         -1.4967     -1.5005    -1.50050    -1.50050
# 2         -1.4982     -1.4985    -1.49850    -1.49850
# 3         -1.4963     -1.4975    -1.49750    -1.49760
# 4         -1.4958     -1.4959    -1.49590    -1.49590
# ...           ...         ...         ...         ...
# 58504     -1.5023     -1.4933    -1.49330    -1.49330
# 58505     -1.5024     -1.4925    -1.49250    -1.49260
# 58506     -1.5039     -1.4911    -1.49135    -1.49125
# 58507     -1.5030     -1.4932    -1.49320    -1.49310
# 58508     -1.5036     -1.4945    -1.49460    -1.49430
#
# [58509 rows x 48 columns]

# %%
km = KMeans(random_state=42)
visualizer = KElbowVisualizer(km, k=(2,12))
 
visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### The number of clusters should be taken is 6 from elbow method.

# %% [markdown]
# ### Now considering all features.

# %%
kmeans = KMeans(n_clusters=6, random_state=0).fit(X)
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
y_kmeans = kmeans.fit_predict(X)
y_kmeans
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 2, 2, ..., 0, 1, 2])

# %%
X['Cluster'] = y_kmeans
X.head()
# Out:
#       current_1     current_2  current_3  current_4     current_5  current_6  \
# 0 -3.014600e-07  8.260300e-06  -0.000012  -0.000002 -1.438600e-06  -0.000021
# 1  2.913200e-06 -5.247700e-06   0.000003  -0.000006  2.778900e-06  -0.000004
# 2 -2.951700e-06 -3.184000e-06  -0.000016  -0.000001 -1.575300e-06   0.000017
# 3 -1.322600e-06  8.820100e-06  -0.000016  -0.000005 -7.282900e-07   0.000004
# 4 -6.836600e-08  5.666300e-07  -0.000026  -0.000006 -7.940600e-07   0.000013
#
#    current_7  current_8  current_9  current_10  ...  current_40  current_41  \
# 0   0.031718   0.031710   0.031721   -0.032963  ...    -0.63308      2.9646
# 1   0.030804   0.030810   0.030806   -0.033520  ...    -0.59314      7.6252
# 2   0.032877   0.032880   0.032896   -0.029834  ...    -0.63252      2.7784
# 3   0.029410   0.029401   0.029417   -0.030156  ...    -0.62289      6.5534
# 4   0.030119   0.030119   0.030145   -0.031393  ...    -0.63010      4.5155
#
#    current_42  current_43  current_44  current_45  current_46  current_47  \
# 0      8.1198     -1.4961     -1.4961     -1.4961     -1.4996     -1.4996
# 1      6.1690     -1.4967     -1.4967     -1.4967     -1.5005     -1.5005
# 2      5.3017     -1.4983     -1.4983     -1.4982     -1.4985     -1.4985
# 3      6.2606     -1.4963     -1.4963     -1.4963     -1.4975     -1.4975
# 4      9.5231     -1.4958     -1.4958     -1.4958     -1.4959     -1.4959
#
#    current_48  Cluster
# 0     -1.4996        2
# 1     -1.5005        2
# 2     -1.4985        2
# 3     -1.4976        5
# 4     -1.4959        3
#
# [5 rows x 49 columns]

# %%
from pandas.plotting import parallel_coordinates
plt.figure(figsize=(15,8))

parallel_coordinates(X, 'Cluster')
# Out:
# <Axes: >

# %%
kmeans.inertia_
# Out:
# 2204616.499049844

# %%
kmeans = KMeans(n_clusters=6)
kmeans.fit(c)
cluster_labels = kmeans.labels_
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans.transform(c)

# %%
silhouette_samples(c, kmeans.labels_)
# Out:
# array([0.25915588, 0.3260147 , 0.53656007, ..., 0.42623968, 0.06502117,
#        0.56698981])

# %%
silhouette_score(c, kmeans.labels_)
# Out:
# 0.3091692321314432

# %%
sil = []
kmax = 10

for k in range(2, kmax+1):
    kmeans = KMeans(n_clusters = 6).fit(c)
    sil.append(silhouette_score(c, kmeans.labels_, metric = 'euclidean'))
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
sil
# Out:
# [0.3091662774983006,
#  0.30922815601545633,
#  0.30918856648706394,
#  0.30911179675986666,
#  0.3092276056738984,
#  0.3092619924539608,
#  0.30919901993157367,
#  0.3090321840673345,
#  0.3092455476440556]

# %%
plt.plot(sil)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
# Out:
# Text(0, 0.5, 'Silhouette Score')

# %% [markdown]
# ### Clustering using only two features from Bidirectional Elimination.

# %%
df.columns
# Out:
# Index(['current_1', 'current_2', 'current_3', 'current_4', 'current_5',
#        'current_6', 'current_7', 'current_8', 'current_9', 'current_10',
#        'current_11', 'current_12', 'current_13', 'current_14', 'current_15',
#        'current_16', 'current_17', 'current_18', 'current_19', 'current_20',
#        'current_21', 'current_22', 'current_23', 'current_24', 'current_25',
#        'current_26', 'current_27', 'current_28', 'current_29', 'current_30',
#        'current_31', 'current_32', 'current_33', 'current_34', 'current_35',
#        'current_36', 'current_37', 'current_38', 'current_39', 'current_40',
#        'current_41', 'current_42', 'current_43', 'current_44', 'current_45',
#        'current_46', 'current_47', 'current_48', 'output'],
#       dtype='object')

# %%
X1 = df[['current_1', 'current_20']]
X1
# Out:
#           current_1  current_20
# 0     -3.014600e-07     0.89669
# 1      2.913200e-06     0.89583
# 2     -2.951700e-06     0.89583
# 3     -1.322600e-06     0.89481
# 4     -6.836600e-08     0.89656
# ...             ...         ...
# 58504 -9.982500e-06     2.29090
# 58505 -1.055400e-05     2.29200
# 58506 -5.857700e-06     2.29070
# 58507 -4.441100e-06     2.29040
# 58508 -8.853300e-06     2.29290
#
# [58509 rows x 2 columns]

# %%
df_1 = X1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
model=scaler.fit(df_1[['current_1']])
df_1['current_1']=model.transform(df_1[['current_1']])
scaler = MinMaxScaler()
mol = scaler.fit(df_1[['current_20']])
df_1['current_20'] = mol.transform(df_1[['current_20']])
# Out:
# C:\Users\vasuk\AppData\Local\Temp\ipykernel_14816\3527785687.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['current_1']=model.transform(df_1[['current_1']])
# C:\Users\vasuk\AppData\Local\Temp\ipykernel_14816\3527785687.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['current_20'] = mol.transform(df_1[['current_20']])

# %%
plt.scatter(df_1['current_1'], df_1['current_20'], s=30)
plt.xlabel('current_1', fontsize=15)
plt.ylabel('current_20', fontsize=15);

# %%
X1 = df_1

# %%
km = KMeans(random_state=42)
visualizer = KElbowVisualizer(km, k=(2,12))
 
visualizer.fit(X1)        # Fit the data to the visualizer
visualizer.show()
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
### From Elbow Plot it is recommending to take 5 clusters

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(X1)
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
cluster = kmeans.predict(X1)
cluster
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
df['Cluster'] = cluster
df
# Out:
#           current_1     current_2  current_3  current_4     current_5  \
# 0     -3.014600e-07  8.260300e-06  -0.000012  -0.000002 -1.438600e-06
# 1      2.913200e-06 -5.247700e-06   0.000003  -0.000006  2.778900e-06
# 2     -2.951700e-06 -3.184000e-06  -0.000016  -0.000001 -1.575300e-06
# 3     -1.322600e-06  8.820100e-06  -0.000016  -0.000005 -7.282900e-07
# 4     -6.836600e-08  5.666300e-07  -0.000026  -0.000006 -7.940600e-07
# ...             ...           ...        ...        ...           ...
# 58504 -9.982500e-06  1.854900e-06  -0.000021   0.000017 -5.910200e-06
# 58505 -1.055400e-05  1.983500e-05   0.000031  -0.000018 -6.547550e-05
# 58506 -5.857700e-06  1.859400e-05  -0.000102  -0.000003  3.827500e-06
# 58507 -4.441100e-06  3.396900e-05  -0.000294   0.000005  6.500800e-06
# 58508 -8.853300e-06  5.225900e-05   0.000072   0.000010  3.795600e-06
#
#        current_6  current_7  current_8  current_9  current_10  ...  \
# 0      -0.000021   0.031718   0.031710   0.031721   -0.032963  ...
# 1      -0.000004   0.030804   0.030810   0.030806   -0.033520  ...
# 2       0.000017   0.032877   0.032880   0.032896   -0.029834  ...
# 3       0.000004   0.029410   0.029401   0.029417   -0.030156  ...
# 4       0.000013   0.030119   0.030119   0.030145   -0.031393  ...
# ...          ...        ...        ...        ...         ...  ...
# 58504  -0.000098  -0.083417  -0.083419  -0.083398   -0.111281  ...
# 58505   0.000289  -0.085131  -0.085151  -0.085182   -0.111281  ...
# 58506   0.000117  -0.081989  -0.082008  -0.081906   -0.111281  ...
# 58507   0.000087  -0.081500  -0.081534  -0.081093   -0.111281  ...
# 58508  -0.000032  -0.083034  -0.083086  -0.083159   -0.111281  ...
#
#        current_41  current_42  current_43  current_44  current_45  current_46  \
# 0          2.9646      8.1198     -1.4961     -1.4961     -1.4961     -1.4996
# 1          7.6252      6.1690     -1.4967     -1.4967     -1.4967     -1.5005
# 2          2.7784      5.3017     -1.4983     -1.4983     -1.4982     -1.4985
# 3          6.5534      6.2606     -1.4963     -1.4963     -1.4963     -1.4975
# 4          4.5155      9.5231     -1.4958     -1.4958     -1.4958     -1.4959
# ...           ...         ...         ...         ...         ...         ...
# 58504      1.4641      7.0032     -1.5024     -1.5025     -1.5023     -1.4933
# 58505      3.3275      2.3072     -1.5024     -1.5025     -1.5024     -1.4925
# 58506     18.5458      9.0437     -1.5035     -1.5035     -1.5039     -1.4911
# 58507      1.3890     10.7430     -1.5029     -1.5029     -1.5030     -1.4932
# 58508      1.6026      4.5773     -1.5039     -1.5040     -1.5036     -1.4945
#
#        current_47  current_48  output  Cluster
# 0        -1.49960    -1.49960       1        1
# 1        -1.50050    -1.50050       1        1
# 2        -1.49850    -1.49850       1        1
# 3        -1.49750    -1.49760       1        1
# 4        -1.49590    -1.49590       1        1
# ...           ...         ...     ...      ...
# 58504    -1.49330    -1.49330      11        0
# 58505    -1.49250    -1.49260      11        0
# 58506    -1.49135    -1.49125      11        0
# 58507    -1.49320    -1.49310      11        0
# 58508    -1.49460    -1.49430      11        0
#
# [58509 rows x 50 columns]

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
kmeans.cluster_centers_
# Out:
# array([[0.25063677, 0.84035916],
#        [0.63593777, 0.27805355],
#        [0.30357391, 0.33614861],
#        [0.51730891, 0.60930134],
#        [0.7419725 , 0.82215811]])

# %%
labels = [0, 1, 2, 3, 4]
colors = ["green", "black", "yellow", "blue", "magenta"]

for label, color in zip(labels, colors):
    index = df["Cluster"]==label
    plt.scatter(df_1.loc[index, "current_1"],
                df_1.loc[index, "current_20"],
                c = color,
                s=30)
    
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color="red", marker="s", s=100);

# %%
kmeans.inertia_
# Out:
# 1650.9380713806502

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(c)
cluster_labels = kmeans.labels_
# Out:
# C:\Users\vasuk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans.transform(c)
# Out:
# array([[ 3.88698311, 12.20102842, 12.98997603, 18.84880787,  6.22359472],
#        [ 5.90598943, 16.01574286, 10.42839464, 19.55450396, 10.104598  ],
#        [ 1.94588121, 14.10865191, 13.82163421, 20.66357954,  7.99788962],
#        ...,
#        [18.23254685, 19.51148434,  5.99980787, 14.18921352, 15.06104326],
#        [ 6.16836898, 12.93631081, 14.90610486, 20.03656835,  7.58750036],
#        [ 2.23213727, 14.51599389, 15.1189446 , 21.64265285,  8.81555145]])

# %%
silhouette_samples(c, kmeans.labels_)
# Out:
# array([0.37279674, 0.40713494, 0.54444415, ..., 0.41309076, 0.26804602,
#        0.56445785])

# %%
silhouette_score(c, kmeans.labels_)

# %%
sil = []
kmax = 10

for k in range(2, kmax+1):
    kmeans = KMeans(n_clusters = 5).fit(c)
    sil.append(silhouette_score(c, kmeans.labels_, metric = 'euclidean'))

# %%
import warnings
warnings.filterwarnings("ignore")

! pip install yellowbrick
from yellowbrick.cluster import SilhouetteVisualizer

# %%
visualizer = SilhouetteVisualizer(km)
visualizer.fit(c);

# %%
inertia = []

for k in range(1,16):
    km = KMeans(n_clusters=5)
    km.fit(c)
    inertia.append(km.inertia_)

# %%
inertia

# %%
plt.plot(range(1,16), inertia)
plt.xlabel('K', fontsize=15)
plt.ylabel('inertia', fontsize=15);

# %%
fig, ax = plt.subplots(6, 2, figsize=(15,8))
for k in range(2,12):

    km = KMeans(n_clusters=6)
    q, mod = divmod(k, 2)

    visualizer = SilhouetteVisualizer(km, ax=ax[q-1][mod])
    visualizer.fit(c)
